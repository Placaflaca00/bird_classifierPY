# %% [markdown]
# # 03 — Entrenamiento baseline
#
# **Objetivo:** entrenar el primer cabezal MLP sobre los embeddings BirdNET sin augmentations.
#
# Sirve como **referencia** contra la cual comparar todos los experimentos siguientes.
#
# Pasos:
# - Clonar repo + `pip install -e .` en Colab.
# - `from src.training.train import train`.
# - Llamar `train(config_overrides={...})` con hiperparámetros baseline.
# - Loggear todo a W&B (proyecto `bird-classifier-py`, tag `baseline`).

# %%
# TODO: implementar
