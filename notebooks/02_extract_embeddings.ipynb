# %% [markdown]
# # 02 — Extracción de embeddings con BirdNET
#
# **Objetivo:** correr el modelo BirdNET (TFLite) sobre todos los clips de `data/raw/` y guardar embeddings 320-dim en `data/processed/`.
#
# Pasos:
# - Clonar el repo y `pip install -e .`.
# - Cargar el `.tflite` de BirdNET (descargado o desde un mirror).
# - Para cada clip: resamplear a 48 kHz, partir en ventanas de 3 s, correr el modelo, promediar embeddings.
# - Persistir `embeddings.npy` (N, 320) + `labels.npy` (N,) + `index.parquet` (mapeo i → metadata).

# %%
# TODO: implementar
