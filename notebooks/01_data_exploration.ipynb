# %% [markdown]
# # 01 — Exploración de datos
#
# **Objetivo:** entender el dataset crudo descargado de Xeno-canto antes de extraer embeddings.
#
# Tareas a cubrir:
# - Cargar `metadata.parquet` y validarlo contra `src.data.schemas.MetadataSchema`.
# - Distribución de clips por especie (¿hay desbalance grave?).
# - Distribución de duración, sample rate y rating Xeno-canto.
# - Detectar especies con muy pocos ejemplos (< N) para excluir o agrupar.
# - Plot de espectrogramas de ejemplo por especie.

# %%
# TODO: implementar
