# %% [markdown]
# # 05 — Export a ONNX
#
# **Objetivo:** convertir el mejor checkpoint de Lightning a ONNX para servir desde AWS Lambda con `onnxruntime`.
#
# Pasos:
# - Cargar el `.ckpt` desde W&B artifacts.
# - Llamar `model.to_onnx(path, input_sample, ...)`.
# - Validar que ONNX produce las mismas salidas que el checkpoint PyTorch (test de regresión).
# - Subir el `.onnx` a `s3://${S3_BUCKET_MODELS}/...` y registrarlo como W&B artifact.

# %%
# TODO: implementar
